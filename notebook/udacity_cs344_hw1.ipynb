# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrestl10/Andrestl10.github.io/blob/main/notebook/udacity_cs344_hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clonar el repositorio y preparar el entorno
# !git clone https://github.com/depctg/udacity-cs344-colab
# !pip install git+git://github.com/depctg/nvcc4jupyter.git

# Cargar el plugin CUDA
# %config NVCCPluginV2.static_dir = True
# %config NVCCPluginV2.relative_dir = "udacity-cs344-colab/src/HW1"
# %load_ext nvcc_plugin

# Crear directorio de compilación y generar Makefiles
# !mkdir -p udacity-cs344-colab/build
# %cd udacity-cs344-colab/build
# !cmake ../src
# !make  # Importante para compilar los ejecutables
# Out:
# fatal: destination path 'udacity-cs344-colab' already exists and is not an empty directory.
# ...
#   Cloning git://github.com/depctg/nvcc4jupyter.git to /tmp/pip-req-build-c1j0_689
#   Running command git clone --filter=blob:none --quiet git://github.com/depctg/nvcc4jupyter.git /tmp/pip-req-build-c1j0_689
#   fatal: unable to connect to github.com:
#   github.com[0: 140.82.112.3]: errno=Connection timed out
#
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet git://github.com/depctg/nvcc4jupyter.git /tmp/pip-req-build-c1j0_689 did not run successfully.
#   │ exit code: 128
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git clone --filter=blob:none --quiet git://github.com/depctg/nvcc4jupyter.git /tmp/pip-req-build-c1j0_689 did not run successfully.
# │ exit code: 128
# ╰─> See above for output.
#
# ...

# %%
# !apt-get update
# !apt-get install -y python3-pycuda
# !pip install pycuda
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,784 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,538 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# !nvidia-smi
# Out:
# Fri Mar 28 04:27:17 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0             33W /   70W |     104MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import numpy as np
import pycuda.driver as cuda
import pycuda.autoinit
from pycuda.compiler import SourceModule
import cv2
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-f9c01ecbb44a> in <cell line: 0>()
#       1 import numpy as np
# ----> 2 import pycuda.driver as cuda
#       3 import pycuda.autoinit
#       4 from pycuda.compiler import SourceModule
#       5 import cv2
#
# /usr/lib/python3/dist-packages/pycuda/driver.py in <module>
#      63
#      64 try:
# ---> 65     from pycuda._driver import *  # noqa
#      66 except ImportError as e:
#      67     if "_v2" in str(e):
#
# ModuleNotFoundError: No module named 'pycuda._driver'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ...

# %%
# Out:
#   File "<ipython-input-19-54b99a0fc7ce>", line 36
#     greyImage[idx] = static_cast<unsigned char>(0.299f * pixel.x + 0.587f * pixel.y + 0.114f * pixel.z);
#                                                     ^
# SyntaxError: invalid decimal literal

# %%
# plot output images
import matplotlib.pyplot as plt
_,ax = plt.subplots(2,2, dpi=150)

ax[0][0].imshow(plt.imread("/content/udacity-cs344-colab/src/HW1/cinque_terre_small.jpg"))
ax[0][0].set_title("original")
ax[0][0].grid(False)

ax[0][1].imshow(plt.imread("HW1_output.png"))
ax[0][1].set_title("output")
ax[0][1].grid(False)

ax[1][0].imshow(plt.imread("HW1_reference.png"))
ax[1][0].set_title("reference")
ax[1][0].grid(False)

ax[1][1].imshow(plt.imread("HW1_differenceImage.png"))
ax[1][1].set_title("difference")
ax[1][1].grid(False)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-ad3b253ab332> in <cell line: 0>()
#       7 ax[0][0].grid(False)
#       8
# ----> 9 ax[0][1].imshow(plt.imread("HW1_output.png"))
#      10 ax[0][1].set_title("output")
#      11 ax[0][1].grid(False)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2611         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2612 ) -> np.ndarray:
# -> 2613     return matplotlib.image.imread(fname, format)
#    2614
#    2615
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in imread(fname, format)
#    1500             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1501             )
# -> 1502     with img_open(fname) as image:
#    1503         return (_pil_png_to_float_array(image)
# ...

# %%
import os
print(os.path.exists("HW1_output.png"))
# Out:
# False
